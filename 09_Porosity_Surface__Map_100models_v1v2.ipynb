# %% [markdown]
# <a href="https://colab.research.google.com/github/sergioGarcia91/TRE_NN_MesaLosSantos/blob/main/09_Porosity_Surface__Map_100models_v1v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import joblib
import matplotlib.pyplot as plt
import seaborn as sns
import os
import geopandas as gp

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Change letter

# %%
# !wget https://github.com/justrajdeep/fonts/raw/master/Times%20New%20Roman.ttf
# Out:
# --2025-01-06 12:23:00--  https://github.com/justrajdeep/fonts/raw/master/Times%20New%20Roman.ttf
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/justrajdeep/fonts/master/Times%20New%20Roman.ttf [following]
# --2025-01-06 12:23:00--  https://raw.githubusercontent.com/justrajdeep/fonts/master/Times%20New%20Roman.ttf
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 834452 (815K) [application/octet-stream]
# Saving to: ‘Times New Roman.ttf’
#
# Times New Roman.ttf 100%[===================>] 814.89K  --.-KB/s    in 0.06s
#
# 2025-01-06 12:23:00 (14.1 MB/s) - ‘Times New Roman.ttf’ saved [834452/834452]

# %%
import matplotlib.font_manager as fm

# %%
font_path = 'Times New Roman.ttf'
font_prop = fm.FontProperties(fname=font_path)
fm.fontManager.addfont(font_path)

font_name = font_prop.get_name()
font_name
# Out:
# 'Times New Roman'

# %%
plt.rcParams['font.family'] = font_name

# %% [markdown]
# # Load data

# %%
path_save_plots = '/content/drive/MyDrive/Manuscritos_Investigacion/ModelosGeofisica_NN_MesaLosSantos_Congreso2023/Figures/'
path_save_models = '/content/drive/MyDrive/Manuscritos_Investigacion/ModelosGeofisica_NN_MesaLosSantos_Congreso2023/100NN_models_maps/'
path_shapefiles = '/content/drive/MyDrive/Manuscritos_Investigacion/ModelosGeofisica_NN_MesaLosSantos_Congreso2023/Shapes/'
path_save_models2 = '/content/drive/MyDrive/Manuscritos_Investigacion/ModelosGeofisica_NN_MesaLosSantos_Congreso2023/100NN_models_maps_v2/'

# %%
faults = 'Fallas_Mesa_corregido2.shp'
faults = gp.read_file(path_shapefiles + faults)
faults.plot()
# Out:
# <Axes: >

# %%
geo = 'geologia_mesa_2.shp'
geo = gp.read_file(path_shapefiles + geo)
geo.plot()
# Out:
# <Axes: >

# %% [markdown]
# ## CSV map

# %%
dfMapaSup = pd.read_csv(path_save_models + 'geo_mapa_sup2.csv')
dfMapaSup.columns = ['coorX', 'coorY', 'coorZ', 'distFault', 'Unidad']
dfMapaSup.head()
# Out:
#         coorX       coorY   coorZ   distFault   Unidad
# 0  1109036.77  1259898.34  1284.0   48.773613  K1ls_mi
# 1  1109136.77  1259898.34  1309.0   99.600276  K1ls_mi
# 2  1109236.77  1259898.34  1317.0  161.484813  K1ls_mi
# 3  1109336.77  1259898.34  1330.0  247.283448  K1ls_mi
# 4  1109436.77  1259898.34  1350.0  340.903116  K1ls_mi

# %%
dfMapaSup['Unidad'].unique()
# Out:
# array(['K1ls_mi', 'J1-2j', 'OSs', 'J1gp', 'K1ls_mm', 'K1ls_ms', 'K1r',
#        'K1p', 'K1t'], dtype=object)

# %% [markdown]
# ## Data normalization

# %%
dfMapaSup['codigoUnidad'] = dfMapaSup['Unidad'].replace({'OSs':0, #silgara
                                                         'J1gp':1, #granito
                                                         'J1-2j':2, #jordan
                                                         'K1ls_mi':3, #santos inf
                                                         'K1ls_mm':4, #santos med
                                                         'K1ls_ms':5, #santo sup
                                                         'K1r':6, #rosablanca
                                                         'K1p':7, #paja
                                                         'K1t':8}) #tablazo
# Out:
# <ipython-input-12-64f375b3c396>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dfMapaSup['codigoUnidad'] = dfMapaSup['Unidad'].replace({'OSs':0, #silgara

# %%
dfMapaSup['X_norm'] = (dfMapaSup['coorX'] - 1096700) / (1120100 - 1096700)
dfMapaSup['Y_norm'] = (dfMapaSup['coorY'] - 1235500) / (1260100 - 1235500)
dfMapaSup['Z_norm'] = (dfMapaSup['coorZ'] - (0)) / (1830 - (0))
dfMapaSup['Df_norm'] = (dfMapaSup['distFault'] - (000)) / (3000 - (000))
dfMapaSup.head()
# Out:
#         coorX       coorY   coorZ   distFault   Unidad  codigoUnidad  \
# 0  1109036.77  1259898.34  1284.0   48.773613  K1ls_mi             3
# 1  1109136.77  1259898.34  1309.0   99.600276  K1ls_mi             3
# 2  1109236.77  1259898.34  1317.0  161.484813  K1ls_mi             3
# 3  1109336.77  1259898.34  1330.0  247.283448  K1ls_mi             3
# 4  1109436.77  1259898.34  1350.0  340.903116  K1ls_mi             3
#
#      X_norm    Y_norm    Z_norm   Df_norm
# 0  0.527212  0.991802  0.701639  0.016258
# 1  0.531486  0.991802  0.715301  0.033200
# 2  0.535759  0.991802  0.719672  0.053828
# 3  0.540033  0.991802  0.726776  0.082428
# 4  0.544306  0.991802  0.737705  0.113634

# %%
mapaSupEntrada = dfMapaSup[['X_norm', 'Y_norm',	'Z_norm',	'Df_norm', 'codigoUnidad']]
mapaSupEntrada
# Out:
#          X_norm    Y_norm    Z_norm   Df_norm  codigoUnidad
# 0      0.527212  0.991802  0.701639  0.016258             3
# 1      0.531486  0.991802  0.715301  0.033200             3
# 2      0.535759  0.991802  0.719672  0.053828             3
# 3      0.540033  0.991802  0.726776  0.082428             3
# 4      0.544306  0.991802  0.737705  0.113634             3
# ...         ...       ...       ...       ...           ...
# 40820  0.467383  0.008063  0.240999  0.628693             2
# 40821  0.450289  0.003998  0.240984  0.696013             2
# 40822  0.454563  0.003998  0.241530  0.724802             2
# 40823  0.458836  0.003998  0.239966  0.699951             2
# 40824  0.463110  0.003998  0.241530  0.675826             2
#
# [40825 rows x 5 columns]

# %%
mapaSupEntrada  = pd.get_dummies(mapaSupEntrada, columns=['codigoUnidad'],
                                 prefix='',
                                 dtype=int)

mapaSupEntrada.head()
# Out:
#      X_norm    Y_norm    Z_norm   Df_norm  _0  _1  _2  _3  _4  _5  _6  _7  _8
# 0  0.527212  0.991802  0.701639  0.016258   0   0   0   1   0   0   0   0   0
# 1  0.531486  0.991802  0.715301  0.033200   0   0   0   1   0   0   0   0   0
# 2  0.535759  0.991802  0.719672  0.053828   0   0   0   1   0   0   0   0   0
# 3  0.540033  0.991802  0.726776  0.082428   0   0   0   1   0   0   0   0   0
# 4  0.544306  0.991802  0.737705  0.113634   0   0   0   1   0   0   0   0   0

# %% [markdown]
# # Models list

# %% [markdown]
# ## v1

# %%
models_list = os.listdir(path_save_models)
models_list = [model for model in models_list if model.endswith('.pkl')]
print(len(models_list))
models_list
# Out:
# 100
# ['model_map_NN_001.pkl',
#  'model_map_NN_002.pkl',
#  'model_map_NN_003.pkl',
#  'model_map_NN_004.pkl',
#  'model_map_NN_005.pkl',
#  'model_map_NN_006.pkl',
#  'model_map_NN_007.pkl',
#  'model_map_NN_008.pkl',
#  'model_map_NN_009.pkl',
#  'model_map_NN_010.pkl',
#  'model_map_NN_011.pkl',
#  'model_map_NN_012.pkl',
#  'model_map_NN_013.pkl',
#  'model_map_NN_014.pkl',
#  'model_map_NN_015.pkl',
#  'model_map_NN_016.pkl',
#  'model_map_NN_017.pkl',
#  'model_map_NN_018.pkl',
#  'model_map_NN_019.pkl',
#  'model_map_NN_020.pkl',
#  'model_map_NN_021.pkl',
#  'model_map_NN_022.pkl',
#  'model_map_NN_023.pkl',
#  'model_map_NN_024.pkl',
#  'model_map_NN_025.pkl',
#  'model_map_NN_026.pkl',
#  'model_map_NN_027.pkl',
#  'model_map_NN_028.pkl',
#  'model_map_NN_029.pkl',
#  'model_map_NN_030.pkl',
#  'model_map_NN_031.pkl',
#  'model_map_NN_032.pkl',
#  'model_map_NN_033.pkl',
#  'model_map_NN_034.pkl',
#  'model_map_NN_035.pkl',
#  'model_map_NN_036.pkl',
#  'model_map_NN_037.pkl',
#  'model_map_NN_038.pkl',
#  'model_map_NN_039.pkl',
#  'model_map_NN_040.pkl',
#  'model_map_NN_041.pkl',
#  'model_map_NN_042.pkl',
#  'model_map_NN_043.pkl',
#  'model_map_NN_044.pkl',
#  'model_map_NN_045.pkl',
#  'model_map_NN_046.pkl',
#  'model_map_NN_047.pkl',
#  'model_map_NN_048.pkl',
#  'model_map_NN_049.pkl',
#  'model_map_NN_050.pkl',
#  'model_map_NN_051.pkl',
#  'model_map_NN_052.pkl',
#  'model_map_NN_053.pkl',
#  'model_map_NN_054.pkl',
#  'model_map_NN_055.pkl',
#  'model_map_NN_056.pkl',
#  'model_map_NN_057.pkl',
#  'model_map_NN_058.pkl',
#  'model_map_NN_059.pkl',
#  'model_map_NN_060.pkl',
#  'model_map_NN_061.pkl',
#  'model_map_NN_062.pkl',
#  'model_map_NN_063.pkl',
#  'model_map_NN_064.pkl',
#  'model_map_NN_065.pkl',
#  'model_map_NN_066.pkl',
#  'model_map_NN_067.pkl',
#  'model_map_NN_068.pkl',
#  'model_map_NN_069.pkl',
#  'model_map_NN_070.pkl',
#  'model_map_NN_071.pkl',
#  'model_map_NN_072.pkl',
#  'model_map_NN_073.pkl',
#  'model_map_NN_074.pkl',
#  'model_map_NN_075.pkl',
#  'model_map_NN_076.pkl',
#  'model_map_NN_077.pkl',
#  'model_map_NN_078.pkl',
#  'model_map_NN_079.pkl',
#  'model_map_NN_080.pkl',
#  'model_map_NN_081.pkl',
#  'model_map_NN_082.pkl',
#  'model_map_NN_083.pkl',
#  'model_map_NN_084.pkl',
#  'model_map_NN_085.pkl',
#  'model_map_NN_086.pkl',
#  'model_map_NN_087.pkl',
#  'model_map_NN_088.pkl',
#  'model_map_NN_089.pkl',
#  'model_map_NN_090.pkl',
#  'model_map_NN_091.pkl',
#  'model_map_NN_092.pkl',
#  'model_map_NN_093.pkl',
#  'model_map_NN_094.pkl',
#  'model_map_NN_095.pkl',
#  'model_map_NN_096.pkl',
#  'model_map_NN_097.pkl',
#  'model_map_NN_098.pkl',
#  'model_map_NN_099.pkl',
#  'model_map_NN_100.pkl']

# %% [markdown]
# ## v2

# %%
models_list2 = os.listdir(path_save_models2)
models_list2 = [model for model in models_list2 if model.endswith('.pkl')]
print(len(models_list2))
models_list2
# Out:
# 100
# ['model_map2_NN_001.pkl',
#  'model_map2_NN_002.pkl',
#  'model_map2_NN_003.pkl',
#  'model_map2_NN_004.pkl',
#  'model_map2_NN_005.pkl',
#  'model_map2_NN_006.pkl',
#  'model_map2_NN_007.pkl',
#  'model_map2_NN_008.pkl',
#  'model_map2_NN_009.pkl',
#  'model_map2_NN_010.pkl',
#  'model_map2_NN_011.pkl',
#  'model_map2_NN_012.pkl',
#  'model_map2_NN_013.pkl',
#  'model_map2_NN_014.pkl',
#  'model_map2_NN_015.pkl',
#  'model_map2_NN_016.pkl',
#  'model_map2_NN_017.pkl',
#  'model_map2_NN_018.pkl',
#  'model_map2_NN_019.pkl',
#  'model_map2_NN_020.pkl',
#  'model_map2_NN_021.pkl',
#  'model_map2_NN_022.pkl',
#  'model_map2_NN_023.pkl',
#  'model_map2_NN_024.pkl',
#  'model_map2_NN_025.pkl',
#  'model_map2_NN_026.pkl',
#  'model_map2_NN_027.pkl',
#  'model_map2_NN_028.pkl',
#  'model_map2_NN_029.pkl',
#  'model_map2_NN_030.pkl',
#  'model_map2_NN_031.pkl',
#  'model_map2_NN_032.pkl',
#  'model_map2_NN_033.pkl',
#  'model_map2_NN_034.pkl',
#  'model_map2_NN_035.pkl',
#  'model_map2_NN_036.pkl',
#  'model_map2_NN_037.pkl',
#  'model_map2_NN_038.pkl',
#  'model_map2_NN_039.pkl',
#  'model_map2_NN_040.pkl',
#  'model_map2_NN_041.pkl',
#  'model_map2_NN_042.pkl',
#  'model_map2_NN_043.pkl',
#  'model_map2_NN_044.pkl',
#  'model_map2_NN_045.pkl',
#  'model_map2_NN_046.pkl',
#  'model_map2_NN_047.pkl',
#  'model_map2_NN_048.pkl',
#  'model_map2_NN_049.pkl',
#  'model_map2_NN_050.pkl',
#  'model_map2_NN_051.pkl',
#  'model_map2_NN_052.pkl',
#  'model_map2_NN_053.pkl',
#  'model_map2_NN_054.pkl',
#  'model_map2_NN_055.pkl',
#  'model_map2_NN_056.pkl',
#  'model_map2_NN_057.pkl',
#  'model_map2_NN_058.pkl',
#  'model_map2_NN_059.pkl',
#  'model_map2_NN_060.pkl',
#  'model_map2_NN_061.pkl',
#  'model_map2_NN_062.pkl',
#  'model_map2_NN_063.pkl',
#  'model_map2_NN_064.pkl',
#  'model_map2_NN_065.pkl',
#  'model_map2_NN_066.pkl',
#  'model_map2_NN_067.pkl',
#  'model_map2_NN_068.pkl',
#  'model_map2_NN_069.pkl',
#  'model_map2_NN_070.pkl',
#  'model_map2_NN_071.pkl',
#  'model_map2_NN_072.pkl',
#  'model_map2_NN_073.pkl',
#  'model_map2_NN_074.pkl',
#  'model_map2_NN_075.pkl',
#  'model_map2_NN_076.pkl',
#  'model_map2_NN_077.pkl',
#  'model_map2_NN_078.pkl',
#  'model_map2_NN_079.pkl',
#  'model_map2_NN_080.pkl',
#  'model_map2_NN_081.pkl',
#  'model_map2_NN_082.pkl',
#  'model_map2_NN_083.pkl',
#  'model_map2_NN_084.pkl',
#  'model_map2_NN_085.pkl',
#  'model_map2_NN_086.pkl',
#  'model_map2_NN_087.pkl',
#  'model_map2_NN_088.pkl',
#  'model_map2_NN_089.pkl',
#  'model_map2_NN_090.pkl',
#  'model_map2_NN_091.pkl',
#  'model_map2_NN_092.pkl',
#  'model_map2_NN_093.pkl',
#  'model_map2_NN_094.pkl',
#  'model_map2_NN_095.pkl',
#  'model_map2_NN_096.pkl',
#  'model_map2_NN_097.pkl',
#  'model_map2_NN_098.pkl',
#  'model_map2_NN_099.pkl',
#  'model_map2_NN_100.pkl']

# %% [markdown]
# # Predict

# %% [markdown]
# # Thesis model

# %%
# !wget https://github.com/sergioGarcia91/AplicativoMesaLosSantos/raw/refs/heads/main/modelosNN/porosidadNNrelu_hl25_8_5Sc32.pkl
# Out:
# --2025-01-06 12:30:29--  https://github.com/sergioGarcia91/AplicativoMesaLosSantos/raw/refs/heads/main/modelosNN/porosidadNNrelu_hl25_8_5Sc32.pkl
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/sergioGarcia91/AplicativoMesaLosSantos/refs/heads/main/modelosNN/porosidadNNrelu_hl25_8_5Sc32.pkl [following]
# --2025-01-06 12:30:29--  https://raw.githubusercontent.com/sergioGarcia91/AplicativoMesaLosSantos/refs/heads/main/modelosNN/porosidadNNrelu_hl25_8_5Sc32.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7545 (7.4K) [application/octet-stream]
# Saving to: ‘porosidadNNrelu_hl25_8_5Sc32.pkl.1’
#
# porosidadNNrelu_hl2 100%[===================>]   7.37K  --.-KB/s    in 0s
#
# 2025-01-06 12:30:29 (62.4 MB/s) - ‘porosidadNNrelu_hl25_8_5Sc32.pkl.1’ saved [7545/7545]

# %%
model_thesis = 'porosidadNNrelu_hl25_8_5Sc32.pkl'
model_thesis = joblib.load(model_thesis)

model_thesis
# Out:
# MLPRegressor(alpha=1e-05, early_stopping=True, hidden_layer_sizes=(25, 8, 5),
#              max_iter=6000, solver='lbfgs', verbose=True)

# %%
df_thesis = dfMapaSup.copy()
df_thesis['X_norm'] = (df_thesis['coorX'] - 1096700) / (1120100 - 1096700)
df_thesis['Y_norm'] = (df_thesis['coorY'] - 1235500) / (1260100 - 1235500)
df_thesis['Z_norm'] = (df_thesis['coorZ'] - (-150)) / (1830 - (-150))
df_thesis['Df_norm'] = (df_thesis['distFault'] - (000)) / (3000 - (000))

df_thesis = df_thesis[['X_norm', 'Y_norm',	'Z_norm',	'Df_norm', 'codigoUnidad']]

df_thesis.head()
# Out:
#      X_norm    Y_norm    Z_norm   Df_norm  codigoUnidad
# 0  0.527212  0.991802  0.724242  0.016258             3
# 1  0.531486  0.991802  0.736869  0.033200             3
# 2  0.535759  0.991802  0.740909  0.053828             3
# 3  0.540033  0.991802  0.747475  0.082428             3
# 4  0.544306  0.991802  0.757576  0.113634             3

# %%
dfMapaSup['Porosity thesis'] = model_thesis.predict(df_thesis)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(

# %%
dfMapaSup.head()
# Out:
#         coorX       coorY   coorZ   distFault   Unidad  codigoUnidad  \
# 0  1109036.77  1259898.34  1284.0   48.773613  K1ls_mi             3
# 1  1109136.77  1259898.34  1309.0   99.600276  K1ls_mi             3
# 2  1109236.77  1259898.34  1317.0  161.484813  K1ls_mi             3
# 3  1109336.77  1259898.34  1330.0  247.283448  K1ls_mi             3
# 4  1109436.77  1259898.34  1350.0  340.903116  K1ls_mi             3
#
#      X_norm    Y_norm    Z_norm   Df_norm  Porosity thesis  Mean 200models  \
# 0  0.527212  0.991802  0.701639  0.016258         4.801592        2.326327
# 1  0.531486  0.991802  0.715301  0.033200         5.168388        2.398750
# 2  0.535759  0.991802  0.719672  0.053828         5.378989        2.473268
# 3  0.540033  0.991802  0.726776  0.082428         5.702990        2.608925
# 4  0.544306  0.991802  0.737705  0.113634         6.122034        2.706662
#
#    Std 200models
# 0       0.441731
# 1       0.493027
# 2       0.714161
# 3       1.132175
# 4       1.535511

# %% [markdown]
# ## 100 models - v1

# %%
models_list
# Out:
# ['model_map_NN_001.pkl',
#  'model_map_NN_002.pkl',
#  'model_map_NN_003.pkl',
#  'model_map_NN_004.pkl',
#  'model_map_NN_005.pkl',
#  'model_map_NN_006.pkl',
#  'model_map_NN_007.pkl',
#  'model_map_NN_008.pkl',
#  'model_map_NN_009.pkl',
#  'model_map_NN_010.pkl',
#  'model_map_NN_011.pkl',
#  'model_map_NN_012.pkl',
#  'model_map_NN_013.pkl',
#  'model_map_NN_014.pkl',
#  'model_map_NN_015.pkl',
#  'model_map_NN_016.pkl',
#  'model_map_NN_017.pkl',
#  'model_map_NN_018.pkl',
#  'model_map_NN_019.pkl',
#  'model_map_NN_020.pkl',
#  'model_map_NN_021.pkl',
#  'model_map_NN_022.pkl',
#  'model_map_NN_023.pkl',
#  'model_map_NN_024.pkl',
#  'model_map_NN_025.pkl',
#  'model_map_NN_026.pkl',
#  'model_map_NN_027.pkl',
#  'model_map_NN_028.pkl',
#  'model_map_NN_029.pkl',
#  'model_map_NN_030.pkl',
#  'model_map_NN_031.pkl',
#  'model_map_NN_032.pkl',
#  'model_map_NN_033.pkl',
#  'model_map_NN_034.pkl',
#  'model_map_NN_035.pkl',
#  'model_map_NN_036.pkl',
#  'model_map_NN_037.pkl',
#  'model_map_NN_038.pkl',
#  'model_map_NN_039.pkl',
#  'model_map_NN_040.pkl',
#  'model_map_NN_041.pkl',
#  'model_map_NN_042.pkl',
#  'model_map_NN_043.pkl',
#  'model_map_NN_044.pkl',
#  'model_map_NN_045.pkl',
#  'model_map_NN_046.pkl',
#  'model_map_NN_047.pkl',
#  'model_map_NN_048.pkl',
#  'model_map_NN_049.pkl',
#  'model_map_NN_050.pkl',
#  'model_map_NN_051.pkl',
#  'model_map_NN_052.pkl',
#  'model_map_NN_053.pkl',
#  'model_map_NN_054.pkl',
#  'model_map_NN_055.pkl',
#  'model_map_NN_056.pkl',
#  'model_map_NN_057.pkl',
#  'model_map_NN_058.pkl',
#  'model_map_NN_059.pkl',
#  'model_map_NN_060.pkl',
#  'model_map_NN_061.pkl',
#  'model_map_NN_062.pkl',
#  'model_map_NN_063.pkl',
#  'model_map_NN_064.pkl',
#  'model_map_NN_065.pkl',
#  'model_map_NN_066.pkl',
#  'model_map_NN_067.pkl',
#  'model_map_NN_068.pkl',
#  'model_map_NN_069.pkl',
#  'model_map_NN_070.pkl',
#  'model_map_NN_071.pkl',
#  'model_map_NN_072.pkl',
#  'model_map_NN_073.pkl',
#  'model_map_NN_074.pkl',
#  'model_map_NN_075.pkl',
#  'model_map_NN_076.pkl',
#  'model_map_NN_077.pkl',
#  'model_map_NN_078.pkl',
#  'model_map_NN_079.pkl',
#  'model_map_NN_080.pkl',
#  'model_map_NN_081.pkl',
#  'model_map_NN_082.pkl',
#  'model_map_NN_083.pkl',
#  'model_map_NN_084.pkl',
#  'model_map_NN_085.pkl',
#  'model_map_NN_086.pkl',
#  'model_map_NN_087.pkl',
#  'model_map_NN_088.pkl',
#  'model_map_NN_089.pkl',
#  'model_map_NN_090.pkl',
#  'model_map_NN_091.pkl',
#  'model_map_NN_092.pkl',
#  'model_map_NN_093.pkl',
#  'model_map_NN_094.pkl',
#  'model_map_NN_095.pkl',
#  'model_map_NN_096.pkl',
#  'model_map_NN_097.pkl',
#  'model_map_NN_098.pkl',
#  'model_map_NN_099.pkl',
#  'model_map_NN_100.pkl']

# %%
df_16models = pd.DataFrame()

for model in models_list:
  nn_model = model[10:16]
  model = joblib.load(path_save_models + model)
  df_16models[nn_model] = model.predict(mapaSupEntrada)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(

# %%
df_16models.head()
# Out:
#      NN_001    NN_002    NN_003    NN_004    NN_005    NN_006    NN_007  \
# 0  2.120447  2.129919  2.382204  2.214787  2.556191  2.278248  2.350383
# 1  2.224223  2.154183  2.345457  2.164291  2.657499  2.283043  2.572694
# 2  2.444724  2.148911  2.270709  2.067390  2.672725  2.250430  2.733317
# 3  2.895113  2.130953  2.164246  1.934201  2.628625  2.225232  2.928339
# 4  3.028129  2.147865  2.053893  1.594577  2.627879  2.231496  3.156167
#
#      NN_008    NN_009    NN_010  ...    NN_091    NN_092    NN_093    NN_094  \
# 0  1.681695  2.141233  2.442732  ...  2.385002  1.874477  1.748499  2.088321
# 1  1.713744  2.057889  2.545929  ...  2.648273  2.018289  2.121234  2.070374
# 2  2.150636  1.942711  2.634237  ...  2.726661  2.179234  2.119882  2.101707
# 3  2.844217  1.810864  2.669763  ...  2.852265  2.401650  1.909897  2.140674
# 4  2.130363  1.744647  2.372689  ...  3.002823  2.646875  1.697094  2.158346
#
#      NN_095    NN_096    NN_097    NN_098    NN_099    NN_100
# 0  2.121709  2.441016  2.539131  3.111516  2.137424  2.076959
# 1  2.095404  2.462870  2.554052  2.788589  1.606253  2.110215
# 2  1.994141  2.470980  2.475625  2.523435  0.931009  2.158124
# 3  1.809735  2.478973  2.438106  2.814159  0.585210  2.193929
# 4  1.866870  2.504736  2.373719  3.128225  0.505392  2.099033
#
# [5 rows x 100 columns]

# %% [markdown]
# ## 100 models - v2

# %%
models_list2
# Out:
# ['model_map2_NN_001.pkl',
#  'model_map2_NN_002.pkl',
#  'model_map2_NN_003.pkl',
#  'model_map2_NN_004.pkl',
#  'model_map2_NN_005.pkl',
#  'model_map2_NN_006.pkl',
#  'model_map2_NN_007.pkl',
#  'model_map2_NN_008.pkl',
#  'model_map2_NN_009.pkl',
#  'model_map2_NN_010.pkl',
#  'model_map2_NN_011.pkl',
#  'model_map2_NN_012.pkl',
#  'model_map2_NN_013.pkl',
#  'model_map2_NN_014.pkl',
#  'model_map2_NN_015.pkl',
#  'model_map2_NN_016.pkl',
#  'model_map2_NN_017.pkl',
#  'model_map2_NN_018.pkl',
#  'model_map2_NN_019.pkl',
#  'model_map2_NN_020.pkl',
#  'model_map2_NN_021.pkl',
#  'model_map2_NN_022.pkl',
#  'model_map2_NN_023.pkl',
#  'model_map2_NN_024.pkl',
#  'model_map2_NN_025.pkl',
#  'model_map2_NN_026.pkl',
#  'model_map2_NN_027.pkl',
#  'model_map2_NN_028.pkl',
#  'model_map2_NN_029.pkl',
#  'model_map2_NN_030.pkl',
#  'model_map2_NN_031.pkl',
#  'model_map2_NN_032.pkl',
#  'model_map2_NN_033.pkl',
#  'model_map2_NN_034.pkl',
#  'model_map2_NN_035.pkl',
#  'model_map2_NN_036.pkl',
#  'model_map2_NN_037.pkl',
#  'model_map2_NN_038.pkl',
#  'model_map2_NN_039.pkl',
#  'model_map2_NN_040.pkl',
#  'model_map2_NN_041.pkl',
#  'model_map2_NN_042.pkl',
#  'model_map2_NN_043.pkl',
#  'model_map2_NN_044.pkl',
#  'model_map2_NN_045.pkl',
#  'model_map2_NN_046.pkl',
#  'model_map2_NN_047.pkl',
#  'model_map2_NN_048.pkl',
#  'model_map2_NN_049.pkl',
#  'model_map2_NN_050.pkl',
#  'model_map2_NN_051.pkl',
#  'model_map2_NN_052.pkl',
#  'model_map2_NN_053.pkl',
#  'model_map2_NN_054.pkl',
#  'model_map2_NN_055.pkl',
#  'model_map2_NN_056.pkl',
#  'model_map2_NN_057.pkl',
#  'model_map2_NN_058.pkl',
#  'model_map2_NN_059.pkl',
#  'model_map2_NN_060.pkl',
#  'model_map2_NN_061.pkl',
#  'model_map2_NN_062.pkl',
#  'model_map2_NN_063.pkl',
#  'model_map2_NN_064.pkl',
#  'model_map2_NN_065.pkl',
#  'model_map2_NN_066.pkl',
#  'model_map2_NN_067.pkl',
#  'model_map2_NN_068.pkl',
#  'model_map2_NN_069.pkl',
#  'model_map2_NN_070.pkl',
#  'model_map2_NN_071.pkl',
#  'model_map2_NN_072.pkl',
#  'model_map2_NN_073.pkl',
#  'model_map2_NN_074.pkl',
#  'model_map2_NN_075.pkl',
#  'model_map2_NN_076.pkl',
#  'model_map2_NN_077.pkl',
#  'model_map2_NN_078.pkl',
#  'model_map2_NN_079.pkl',
#  'model_map2_NN_080.pkl',
#  'model_map2_NN_081.pkl',
#  'model_map2_NN_082.pkl',
#  'model_map2_NN_083.pkl',
#  'model_map2_NN_084.pkl',
#  'model_map2_NN_085.pkl',
#  'model_map2_NN_086.pkl',
#  'model_map2_NN_087.pkl',
#  'model_map2_NN_088.pkl',
#  'model_map2_NN_089.pkl',
#  'model_map2_NN_090.pkl',
#  'model_map2_NN_091.pkl',
#  'model_map2_NN_092.pkl',
#  'model_map2_NN_093.pkl',
#  'model_map2_NN_094.pkl',
#  'model_map2_NN_095.pkl',
#  'model_map2_NN_096.pkl',
#  'model_map2_NN_097.pkl',
#  'model_map2_NN_098.pkl',
#  'model_map2_NN_099.pkl',
#  'model_map2_NN_100.pkl']

# %%
for model in models_list2:
  nn_model = model[11:17] + '_v2'
  model = joblib.load(path_save_models2 + model)
  df_16models[nn_model] = model.predict(mapaSupEntrada)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# <ipython-input-25-aaa7b24794d8>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_16models[nn_model] = model.predict(mapaSupEntrada)

# %%
df_16models.head()
# Out:
#      NN_001    NN_002    NN_003    NN_004    NN_005    NN_006    NN_007  \
# 0  2.120447  2.129919  2.382204  2.214787  2.556191  2.278248  2.350383
# 1  2.224223  2.154183  2.345457  2.164291  2.657499  2.283043  2.572694
# 2  2.444724  2.148911  2.270709  2.067390  2.672725  2.250430  2.733317
# 3  2.895113  2.130953  2.164246  1.934201  2.628625  2.225232  2.928339
# 4  3.028129  2.147865  2.053893  1.594577  2.627879  2.231496  3.156167
#
#      NN_008    NN_009    NN_010  ...  NN_091_v2  NN_092_v2  NN_093_v2  \
# 0  1.681695  2.141233  2.442732  ...   1.326436   2.703965   1.746293
# 1  1.713744  2.057889  2.545929  ...   1.326436   2.641505   1.848250
# 2  2.150636  1.942711  2.634237  ...   1.326436   2.510955   1.831459
# 3  2.844217  1.810864  2.669763  ...   1.388518   2.376801   1.802126
# 4  2.130363  1.744647  2.372689  ...   1.698597   2.404902   1.808898
#
#    NN_094_v2  NN_095_v2  NN_096_v2  NN_097_v2  NN_098_v2  NN_099_v2  NN_100_v2
# 0   2.188756   2.373686   1.795807   2.051309   2.009565   2.693699   2.081640
# 1   2.722137   2.370963   1.809405   2.194550   2.081247   2.497752   3.045682
# 2   2.498565   2.317630   1.771171   2.197972   2.210813   2.257309   4.120947
# 3   2.596983   2.236978   1.719711   2.204588   2.434786   2.032082   5.002940
# 4   3.155003   2.157943   1.676626   2.369018   2.540862   1.846204   6.418071
#
# [5 rows x 200 columns]

# %% [markdown]
# ## Mean and Standard deviation

# %%
dfMapaSup['Mean 200models'] = df_16models.mean(axis=1)
dfMapaSup['Std 200models'] = df_16models.std(axis=1)

dfMapaSup.head()
# Out:
#         coorX       coorY   coorZ   distFault   Unidad  codigoUnidad  \
# 0  1109036.77  1259898.34  1284.0   48.773613  K1ls_mi             3
# 1  1109136.77  1259898.34  1309.0   99.600276  K1ls_mi             3
# 2  1109236.77  1259898.34  1317.0  161.484813  K1ls_mi             3
# 3  1109336.77  1259898.34  1330.0  247.283448  K1ls_mi             3
# 4  1109436.77  1259898.34  1350.0  340.903116  K1ls_mi             3
#
#      X_norm    Y_norm    Z_norm   Df_norm  Porosity thesis  Mean 200models  \
# 0  0.527212  0.991802  0.701639  0.016258         2.045007        2.326327
# 1  0.531486  0.991802  0.715301  0.033200         2.203641        2.398750
# 2  0.535759  0.991802  0.719672  0.053828         2.426700        2.473268
# 3  0.540033  0.991802  0.726776  0.082428         2.696670        2.608925
# 4  0.544306  0.991802  0.737705  0.113634         2.953733        2.706662
#
#    Std 200models
# 0       0.441731
# 1       0.493027
# 2       0.714161
# 3       1.132175
# 4       1.535511

# %% [markdown]
# # Plot

# %%
dfMapaSup.columns
# Out:
# Index(['coorX', 'coorY', 'coorZ', 'distFault', 'Unidad', 'codigoUnidad',
#        'X_norm', 'Y_norm', 'Z_norm', 'Df_norm', 'Porosity thesis',
#        'Mean 200models', 'Std 200models'],
#       dtype='object')

# %%
dfMapaSup.describe().round(2)
# Out:
#             coorX       coorY     coorZ  distFault  codigoUnidad    X_norm  \
# count    40825.00    40825.00  40825.00   40825.00      40825.00  40825.00
# mean   1108740.99  1248026.61   1263.17     522.61          3.85      0.51
# std       5523.04     6250.78    363.08     401.28          2.03      0.24
# min    1097036.77  1235598.34    301.12       0.05          0.00      0.01
# 25%    1104236.77  1242798.34   1040.00     200.96          2.00      0.32
# 50%    1108736.77  1248098.34   1289.00     438.81          5.00      0.51
# 75%    1113236.77  1253298.34   1624.00     759.42          5.00      0.71
# max    1119936.77  1259898.34   1819.00    2605.49          8.00      0.99
#
#          Y_norm    Z_norm   Df_norm  Porosity thesis  Mean 200models  \
# count  40825.00  40825.00  40825.00         40825.00        40825.00
# mean       0.51      0.69      0.17             5.08            4.66
# std        0.25      0.20      0.13             4.43            3.90
# min        0.00      0.16      0.00             0.14           -0.50
# 25%        0.30      0.57      0.07             1.71            1.53
# 50%        0.51      0.70      0.15             3.73            3.69
# 75%        0.72      0.89      0.25             7.10            6.86
# max        0.99      0.99      0.87            28.03           18.10
#
#        Std 200models
# count       40825.00
# mean            2.05
# std             1.02
# min             0.33
# 25%             1.34
# 50%             1.73
# 75%             2.53
# max             7.04

# %%
x_min = dfMapaSup['coorX'].min() - 1000
x_max = dfMapaSup['coorX'].max() + 1000

y_min = dfMapaSup['coorY'].min() - 1000
y_max = dfMapaSup['coorY'].max() + 1000

fig, ax = plt.subplots(1,3, figsize=(15, 7))

mp = ax[0].scatter(dfMapaSup['coorX'], dfMapaSup['coorY'],
              c=dfMapaSup['Porosity thesis'], cmap='jet',
              vmin=0, vmax=25)
geo.boundary.plot(ax=ax[0], color="gray", alpha=0.5)
faults.plot(ax=ax[0], color="black")
ax[0].set_xlim(x_min, x_max)
ax[0].set_ylim(y_min, y_max)
ax[0].set_title('García-Arias  et al. (2024)')
ax[0].grid(ls='--', color='grey', alpha=0.8)

ax[1].scatter(dfMapaSup['coorX'], dfMapaSup['coorY'],
              c=dfMapaSup['Mean 200models'], cmap='jet',
              vmin=0, vmax=25)
geo.boundary.plot(ax=ax[1], color="gray", alpha=0.5)
faults.plot(ax=ax[1], color="black")
ax[1].set_xlim(x_min, x_max)
ax[1].set_ylim(y_min, y_max)
ax[1].set_title('200 models v1+v2 - Mean')
ax[1].grid(ls='--', color='grey', alpha=0.8)

mp2 = ax[2].scatter(dfMapaSup['coorX'], dfMapaSup['coorY'],
                    c=dfMapaSup['Std 200models'], cmap='jet',
                    vmin=1, vmax=6)
geo.boundary.plot(ax=ax[2], color="gray", alpha=0.5)
faults.plot(ax=ax[2], color="black")
ax[2].set_xlim(x_min, x_max)
ax[2].set_ylim(y_min, y_max)
ax[2].set_title('200 models v1+v2 - Std')
ax[2].grid(ls='--', color='grey', alpha=0.8)

plt.colorbar(mp, ax=ax[0:2], shrink=0.5, label='Porosity [%]', orientation='horizontal')
plt.colorbar(mp2, ax=ax[2], shrink=1, label='Porosity [%] - Std', orientation='horizontal')

plt.savefig(path_save_plots + f'Maps_200models_v1v2.png',
            dpi=500,
            bbox_inches = 'tight',
            pad_inches=0.25)

plt.show()

# %% [markdown]
# # End
